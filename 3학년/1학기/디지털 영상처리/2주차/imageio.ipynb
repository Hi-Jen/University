# %%
import matplotlib.image as mpimg  # 영상 입출력 라이브러리
import matplotlib.pyplot as plt   # 영상 화면 보기 라이브러리

img = mpimg.imread("/content/drive/MyDrive/Colab Notebooks/week02/parrot.png")
plt.imshow(img)
plt.show()

# %%
from PIL import Image # Pillow Imae Libarary
import matplotlib.pyplot as plt

im = Image.open("/content/drive/MyDrive/Colab Notebooks/week02/parrot.png")
print(im.width, im.height, im.mode, im.format) # 넓이, 높이, 색상, 파일형식

#im_g = im.convert('L')
#im_g.save("/content/drive/MyDrive/Colab Notebooks/week02/parrot_gray.png")

plt.imshow(im)
#plt.imshow(im_g, cmap='gray')  #회색조 영상을 정확히 보여주기 위한 컬러맵 설정
plt.axis('off')

plt.show()
# Out:
# 453 340 RGB PNG
